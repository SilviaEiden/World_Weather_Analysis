# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | wasilla
# Processing Record 5 of Set 1 | timra
# Processing Record 6 of Set 1 | saldanha
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | micheweni
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | qui nhon
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | lemesos
# City not found. Skipping...
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | bronzani majdan
# Processing Record 19 of Set 1 | kurya
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | grand gaube
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | saint-leu
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | atar
# Processing Record 32 of Set 1 | udachnyy
# Processing Record 33 of Set 1 | aklavik
# Processing Record 34 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 1 | tezu
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | tuktoyaktuk
# Processing Record 39 of Set 1 | patamea
# City not found. Skipping...
# Processing Record 40 of Set 1 | havre-saint-pierre
# Processing Record 41 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 1 | matagami
# Processing Record 43 of Set 1 | anadyr
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | sola
# Processing Record 47 of Set 1 | tahoua
# Processing Record 48 of Set 1 | nosy varika
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | dingle
# Processing Record 1 of Set 2 | dawson creek
# Processing Record 2 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 2 | hithadhoo
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | pevek
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | san quintin
# Processing Record 8 of Set 2 | tadine
# Processing Record 9 of Set 2 | constitucion
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 2 | emba
# Processing Record 13 of Set 2 | berlevag
# Processing Record 14 of Set 2 | ranfurly
# Processing Record 15 of Set 2 | sistranda
# Processing Record 16 of Set 2 | guisa
# Processing Record 17 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 18 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 2 | masallatah
# Processing Record 20 of Set 2 | maniwaki
# Processing Record 21 of Set 2 | cassilandia
# Processing Record 22 of Set 2 | kudahuvadhoo
# Processing Record 23 of Set 2 | yeppoon
# Processing Record 24 of Set 2 | fort nelson
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | flinders
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | sandwick
# Processing Record 30 of Set 2 | marsa matruh
# Processing Record 31 of Set 2 | takoradi
# Processing Record 32 of Set 2 | san patricio
# Processing Record 33 of Set 2 | karcsa
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | ribeira grande
# Processing Record 36 of Set 2 | saint-francois
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | los llanos de aridane
# Processing Record 39 of Set 2 | punta arenas
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | vaini
# Processing Record 42 of Set 2 | carnarvon
# Processing Record 43 of Set 2 | luderitz
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | bongandanga
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | pahrump
# Processing Record 48 of Set 2 | kachiry
# Processing Record 49 of Set 2 | mindelo
# Processing Record 50 of Set 2 | bengkulu
# Processing Record 1 of Set 3 | sao gabriel da cachoeira
# Processing Record 2 of Set 3 | diamantino
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | shubarshi
# Processing Record 5 of Set 3 | beringovskiy
# Processing Record 6 of Set 3 | batticaloa
# Processing Record 7 of Set 3 | thunder bay
# Processing Record 8 of Set 3 | port elizabeth
# Processing Record 9 of Set 3 | narasapur
# Processing Record 10 of Set 3 | certegui
# Processing Record 11 of Set 3 | obo
# Processing Record 12 of Set 3 | faya
# Processing Record 13 of Set 3 | kalevala
# Processing Record 14 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 3 | shingu
# Processing Record 16 of Set 3 | filingue
# Processing Record 17 of Set 3 | nanchong
# Processing Record 18 of Set 3 | oksovskiy
# Processing Record 19 of Set 3 | narsaq
# Processing Record 20 of Set 3 | hongjiang
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | aksu
# Processing Record 23 of Set 3 | husavik
# Processing Record 24 of Set 3 | moose factory
# Processing Record 25 of Set 3 | port alfred
# Processing Record 26 of Set 3 | torbay
# Processing Record 27 of Set 3 | zhuhai
# Processing Record 28 of Set 3 | springfield
# Processing Record 29 of Set 3 | caibarien
# Processing Record 30 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 3 | saint-philippe
# Processing Record 32 of Set 3 | clyde river
# Processing Record 33 of Set 3 | fare
# Processing Record 34 of Set 3 | dikson
# Processing Record 35 of Set 3 | angoche
# Processing Record 36 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 38 of Set 3 | maceio
# Processing Record 39 of Set 3 | yershov
# Processing Record 40 of Set 3 | omboue
# Processing Record 41 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 3 | airai
# Processing Record 43 of Set 3 | te anau
# Processing Record 44 of Set 3 | lar
# Processing Record 45 of Set 3 | teguldet
# Processing Record 46 of Set 3 | peniche
# Processing Record 47 of Set 3 | laguna
# Processing Record 48 of Set 3 | soure
# Processing Record 49 of Set 3 | ginda
# Processing Record 50 of Set 3 | nome
# Processing Record 1 of Set 4 | east london
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | nanortalik
# Processing Record 4 of Set 4 | port lincoln
# Processing Record 5 of Set 4 | melfi
# Processing Record 6 of Set 4 | sinnamary
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | lardos
# Processing Record 9 of Set 4 | ballitoville
# Processing Record 10 of Set 4 | rudnyy
# Processing Record 11 of Set 4 | nueve de julio
# Processing Record 12 of Set 4 | cap malheureux
# Processing Record 13 of Set 4 | paamiut
# Processing Record 14 of Set 4 | ilinge
# Processing Record 15 of Set 4 | chokurdakh
# Processing Record 16 of Set 4 | yurya
# City not found. Skipping...
# Processing Record 17 of Set 4 | lensk
# Processing Record 18 of Set 4 | chabahar
# Processing Record 19 of Set 4 | mahanoro
# Processing Record 20 of Set 4 | smithers
# Processing Record 21 of Set 4 | ponta do sol
# Processing Record 22 of Set 4 | quba
# Processing Record 23 of Set 4 | nago
# Processing Record 24 of Set 4 | saskylakh
# Processing Record 25 of Set 4 | hualmay
# Processing Record 26 of Set 4 | miramar
# Processing Record 27 of Set 4 | baykit
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | pimentel
# Processing Record 30 of Set 4 | amberley
# Processing Record 31 of Set 4 | tabuk
# Processing Record 32 of Set 4 | iqaluit
# Processing Record 33 of Set 4 | mariinsk
# Processing Record 34 of Set 4 | caravelas
# Processing Record 35 of Set 4 | muroto
# Processing Record 36 of Set 4 | puerto madryn
# Processing Record 37 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | dunedin
# Processing Record 40 of Set 4 | torit
# Processing Record 41 of Set 4 | lindsay
# Processing Record 42 of Set 4 | kolomak
# Processing Record 43 of Set 4 | viterbo
# Processing Record 44 of Set 4 | rio cuarto
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | mayo
# Processing Record 47 of Set 4 | puerto ayora
# Processing Record 48 of Set 4 | butaritari
# Processing Record 49 of Set 4 | alghero
# Processing Record 50 of Set 4 | saint anthony
# Processing Record 1 of Set 5 | manzhouli
# Processing Record 2 of Set 5 | lydenburg
# Processing Record 3 of Set 5 | parrita
# Processing Record 4 of Set 5 | guerrero negro
# Processing Record 5 of Set 5 | sur
# Processing Record 6 of Set 5 | humboldt
# Processing Record 7 of Set 5 | hay river
# Processing Record 8 of Set 5 | la ronge
# Processing Record 9 of Set 5 | igarka
# Processing Record 10 of Set 5 | myitkyina
# Processing Record 11 of Set 5 | tambovka
# Processing Record 12 of Set 5 | cairns
# Processing Record 13 of Set 5 | rafaela
# Processing Record 14 of Set 5 | omsukchan
# Processing Record 15 of Set 5 | vaitape
# Processing Record 16 of Set 5 | kavieng
# Processing Record 17 of Set 5 | esperance
# Processing Record 18 of Set 5 | marzuq
# Processing Record 19 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 20 of Set 5 | geraldton
# Processing Record 21 of Set 5 | lata
# Processing Record 22 of Set 5 | bemidji
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | nalut
# Processing Record 25 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 5 | colac
# Processing Record 27 of Set 5 | wunsiedel
# Processing Record 28 of Set 5 | manokwari
# Processing Record 29 of Set 5 | pasighat
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | kurkino
# Processing Record 32 of Set 5 | cookeville
# Processing Record 33 of Set 5 | rawson
# Processing Record 34 of Set 5 | avera
# Processing Record 35 of Set 5 | chuy
# Processing Record 36 of Set 5 | yambio
# Processing Record 37 of Set 5 | rapid valley
# Processing Record 38 of Set 5 | saint-georges
# Processing Record 39 of Set 5 | roma
# Processing Record 40 of Set 5 | tazovskiy
# Processing Record 41 of Set 5 | vila velha
# Processing Record 42 of Set 5 | lokosovo
# Processing Record 43 of Set 5 | namibe
# Processing Record 44 of Set 5 | qasigiannguit
# Processing Record 45 of Set 5 | pio xii
# Processing Record 46 of Set 5 | chipinge
# Processing Record 47 of Set 5 | ico
# Processing Record 48 of Set 5 | yumen
# Processing Record 49 of Set 5 | boguchany
# Processing Record 50 of Set 5 | tiznit
# Processing Record 1 of Set 6 | saint-augustin
# Processing Record 2 of Set 6 | novyy urengoy
# Processing Record 3 of Set 6 | aswan
# Processing Record 4 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 6 | norman wells
# Processing Record 6 of Set 6 | quelimane
# Processing Record 7 of Set 6 | waddan
# Processing Record 8 of Set 6 | santiago del estero
# Processing Record 9 of Set 6 | rocha
# Processing Record 10 of Set 6 | ambulu
# Processing Record 11 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 6 | provideniya
# Processing Record 13 of Set 6 | lixourion
# Processing Record 14 of Set 6 | nikolskoye
# Processing Record 15 of Set 6 | ngunguru
# Processing Record 16 of Set 6 | khash
# Processing Record 17 of Set 6 | kodiak
# Processing Record 18 of Set 6 | solikamsk
# Processing Record 19 of Set 6 | port keats
# Processing Record 20 of Set 6 | codrington
# Processing Record 21 of Set 6 | maba
# Processing Record 22 of Set 6 | meadow lake
# Processing Record 23 of Set 6 | inirida
# Processing Record 24 of Set 6 | qaanaaq
# Processing Record 25 of Set 6 | luquillo
# Processing Record 26 of Set 6 | portland
# Processing Record 27 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 6 | bonavista
# Processing Record 29 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 30 of Set 6 | sao joao da barra
# Processing Record 31 of Set 6 | katsuura
# Processing Record 32 of Set 6 | ahipara
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | monrovia
# Processing Record 35 of Set 6 | pahalgam
# Processing Record 36 of Set 6 | vrangel
# Processing Record 37 of Set 6 | noumea
# Processing Record 38 of Set 6 | mokhsogollokh
# Processing Record 39 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 6 | juifang
# City not found. Skipping...
# Processing Record 41 of Set 6 | poso
# Processing Record 42 of Set 6 | forbes
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | saint george
# Processing Record 45 of Set 6 | palmer
# Processing Record 46 of Set 6 | along
# Processing Record 47 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 6 | porto novo
# Processing Record 49 of Set 6 | korla
# Processing Record 50 of Set 6 | isangel
# Processing Record 1 of Set 7 | malmesbury
# Processing Record 2 of Set 7 | ilhabela
# Processing Record 3 of Set 7 | newberry
# Processing Record 4 of Set 7 | gushikawa
# Processing Record 5 of Set 7 | chapais
# Processing Record 6 of Set 7 | morar
# Processing Record 7 of Set 7 | namuac
# Processing Record 8 of Set 7 | maryborough
# Processing Record 9 of Set 7 | souillac
# Processing Record 10 of Set 7 | talnakh
# Processing Record 11 of Set 7 | bandarbeyla
# Processing Record 12 of Set 7 | kahului
# Processing Record 13 of Set 7 | jalesar
# Processing Record 14 of Set 7 | tamandare
# Processing Record 15 of Set 7 | bambous virieux
# Processing Record 16 of Set 7 | kenai
# Processing Record 17 of Set 7 | ascension
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | hailey
# Processing Record 20 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 7 | umm lajj
# Processing Record 22 of Set 7 | viedma
# Processing Record 23 of Set 7 | jackson
# Processing Record 24 of Set 7 | moctezuma
# Processing Record 25 of Set 7 | bubaque
# Processing Record 26 of Set 7 | lodwar
# Processing Record 27 of Set 7 | mar del plata
# Processing Record 28 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 29 of Set 7 | oranjemund
# Processing Record 30 of Set 7 | kununurra
# Processing Record 31 of Set 7 | den helder
# Processing Record 32 of Set 7 | robat karim
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | longyearbyen
# Processing Record 35 of Set 7 | killybegs
# Processing Record 36 of Set 7 | northam
# Processing Record 37 of Set 7 | coquimbo
# Processing Record 38 of Set 7 | juba
# Processing Record 39 of Set 7 | abengourou
# Processing Record 40 of Set 7 | lompoc
# Processing Record 41 of Set 7 | lulea
# Processing Record 42 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 43 of Set 7 | fairbanks
# Processing Record 44 of Set 7 | nemuro
# Processing Record 45 of Set 7 | namie
# Processing Record 46 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 48 of Set 7 | jalu
# Processing Record 49 of Set 7 | shimoda
# Processing Record 50 of Set 7 | samarai
# Processing Record 1 of Set 8 | bambanglipuro
# Processing Record 2 of Set 8 | viareggio
# Processing Record 3 of Set 8 | amapa
# Processing Record 4 of Set 8 | yanchukan
# City not found. Skipping...
# Processing Record 5 of Set 8 | road town
# Processing Record 6 of Set 8 | hofn
# Processing Record 7 of Set 8 | mount isa
# Processing Record 8 of Set 8 | muisne
# Processing Record 9 of Set 8 | seoul
# Processing Record 10 of Set 8 | kharagpur
# Processing Record 11 of Set 8 | bilibino
# Processing Record 12 of Set 8 | kota kinabalu
# Processing Record 13 of Set 8 | leirvik
# Processing Record 14 of Set 8 | khalkhal
# Processing Record 15 of Set 8 | anjiang
# Processing Record 16 of Set 8 | sefophe
# Processing Record 17 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 8 | klamath falls
# Processing Record 19 of Set 8 | uyemskiy
# Processing Record 20 of Set 8 | genhe
# Processing Record 21 of Set 8 | sangin
# Processing Record 22 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 8 | srednekolymsk
# Processing Record 24 of Set 8 | camocim
# Processing Record 25 of Set 8 | poum
# Processing Record 26 of Set 8 | saint-orens-de-gameville
# Processing Record 27 of Set 8 | belyy yar
# Processing Record 28 of Set 8 | komsomolskiy
# Processing Record 29 of Set 8 | ketchikan
# Processing Record 30 of Set 8 | kavaratti
# Processing Record 31 of Set 8 | scotts valley
# Processing Record 32 of Set 8 | novikovo
# Processing Record 33 of Set 8 | pudozh
# Processing Record 34 of Set 8 | aripuana
# Processing Record 35 of Set 8 | vao
# Processing Record 36 of Set 8 | umba
# Processing Record 37 of Set 8 | ca mau
# Processing Record 38 of Set 8 | tooele
# Processing Record 39 of Set 8 | leh
# Processing Record 40 of Set 8 | marsh harbour
# Processing Record 41 of Set 8 | batsfjord
# Processing Record 42 of Set 8 | tawzar
# City not found. Skipping...
# Processing Record 43 of Set 8 | onalaska
# Processing Record 44 of Set 8 | nishihara
# Processing Record 45 of Set 8 | vestmanna
# Processing Record 46 of Set 8 | evensk
# Processing Record 47 of Set 8 | ligayan
# Processing Record 48 of Set 8 | tacoronte
# Processing Record 49 of Set 8 | sao filipe
# Processing Record 50 of Set 8 | andenes
# Processing Record 1 of Set 9 | dindori
# Processing Record 2 of Set 9 | bira
# Processing Record 3 of Set 9 | sulangan
# Processing Record 4 of Set 9 | turka
# Processing Record 5 of Set 9 | vardo
# Processing Record 6 of Set 9 | charlottetown
# Processing Record 7 of Set 9 | kuala kangsar
# Processing Record 8 of Set 9 | farafangana
# Processing Record 9 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 9 | port blair
# Processing Record 11 of Set 9 | conceicao da barra
# Processing Record 12 of Set 9 | beyla
# Processing Record 13 of Set 9 | vila franca do campo
# Processing Record 14 of Set 9 | nakamura
# Processing Record 15 of Set 9 | morondava
# Processing Record 16 of Set 9 | sorland
# Processing Record 17 of Set 9 | wanning
# Processing Record 18 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 9 | khani
# Processing Record 20 of Set 9 | virginia beach
# Processing Record 21 of Set 9 | kharitonovo
# Processing Record 22 of Set 9 | tateyama
# Processing Record 23 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 24 of Set 9 | haines junction
# Processing Record 25 of Set 9 | dossor
# Processing Record 26 of Set 9 | saravan
# Processing Record 27 of Set 9 | labuhan
# Processing Record 28 of Set 9 | zhangye
# Processing Record 29 of Set 9 | capoterra
# Processing Record 30 of Set 9 | lavras
# Processing Record 31 of Set 9 | kalmunai
# Processing Record 32 of Set 9 | grindavik
# Processing Record 33 of Set 9 | tiarei
# Processing Record 34 of Set 9 | atikokan
# Processing Record 35 of Set 9 | sitka
# Processing Record 36 of Set 9 | quang ngai
# Processing Record 37 of Set 9 | gisborne
# Processing Record 38 of Set 9 | salalah
# Processing Record 39 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 9 | kiama
# Processing Record 41 of Set 9 | bougouni
# Processing Record 42 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 43 of Set 9 | diebougou
# Processing Record 44 of Set 9 | mnogovershinnyy
# Processing Record 45 of Set 9 | le port
# Processing Record 46 of Set 9 | saint-denis
# Processing Record 47 of Set 9 | ayna
# Processing Record 48 of Set 9 | sandakan
# Processing Record 49 of Set 9 | iki-burul
# Processing Record 50 of Set 9 | chumikan
# Processing Record 1 of Set 10 | leningradskiy
# Processing Record 2 of Set 10 | alvaraes
# Processing Record 3 of Set 10 | ugoofaaru
# Processing Record 4 of Set 10 | broken hill
# Processing Record 5 of Set 10 | kuusamo
# Processing Record 6 of Set 10 | hamilton
# Processing Record 7 of Set 10 | moerai
# Processing Record 8 of Set 10 | saint-pierre
# Processing Record 9 of Set 10 | bilma
# Processing Record 10 of Set 10 | kangaatsiaq
# Processing Record 11 of Set 10 | ler
# Processing Record 12 of Set 10 | bone
# Processing Record 13 of Set 10 | shalinskoye
# Processing Record 14 of Set 10 | zwettl
# Processing Record 15 of Set 10 | mingshui
# Processing Record 16 of Set 10 | lazaro cardenas
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | deputatskiy
# Processing Record 19 of Set 10 | arman
# Processing Record 20 of Set 10 | damme
# Processing Record 21 of Set 10 | ajdabiya
# Processing Record 22 of Set 10 | yuci
# Processing Record 23 of Set 10 | torata
# Processing Record 24 of Set 10 | azul
# Processing Record 25 of Set 10 | axim
# Processing Record 26 of Set 10 | hanzhong
# Processing Record 27 of Set 10 | sumbe
# Processing Record 28 of Set 10 | lishan
# Processing Record 29 of Set 10 | port said
# Processing Record 30 of Set 10 | gilgil
# City not found. Skipping...
# Processing Record 31 of Set 10 | pedernales
# Processing Record 32 of Set 10 | opuwo
# Processing Record 33 of Set 10 | preili
# Processing Record 34 of Set 10 | college
# Processing Record 35 of Set 10 | burnie
# Processing Record 36 of Set 10 | kabo
# Processing Record 37 of Set 10 | borba
# Processing Record 38 of Set 10 | male
# Processing Record 39 of Set 10 | puerto maldonado
# Processing Record 40 of Set 10 | riyadh
# Processing Record 41 of Set 10 | klaksvik
# Processing Record 42 of Set 10 | dharchula
# Processing Record 43 of Set 10 | athy
# Processing Record 44 of Set 10 | cockburn town
# Processing Record 45 of Set 10 | sibolga
# Processing Record 46 of Set 10 | puerto ayacucho
# Processing Record 47 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 10 | kodinsk
# Processing Record 49 of Set 10 | flin flon
# Processing Record 50 of Set 10 | methoni
# Processing Record 1 of Set 11 | alcaniz
# Processing Record 2 of Set 11 | daultala
# Processing Record 3 of Set 11 | rincon
# Processing Record 4 of Set 11 | margate
# Processing Record 5 of Set 11 | meulaboh
# Processing Record 6 of Set 11 | kidal
# Processing Record 7 of Set 11 | suntar
# Processing Record 8 of Set 11 | nouakchott
# Processing Record 9 of Set 11 | bobo dioulasso
# Processing Record 10 of Set 11 | saurimo
# Processing Record 11 of Set 11 | neiafu
# Processing Record 12 of Set 11 | mount darwin
# Processing Record 13 of Set 11 | martapura
# Processing Record 14 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 15 of Set 11 | gallup
# Processing Record 16 of Set 11 | alihe
# Processing Record 17 of Set 11 | zhezkazgan
# Processing Record 18 of Set 11 | spring hill
# Processing Record 19 of Set 11 | san cristobal
# Processing Record 20 of Set 11 | rio grande
# Processing Record 21 of Set 11 | caucasia
# Processing Record 22 of Set 11 | kiruna
# Processing Record 23 of Set 11 | conde
# Processing Record 24 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 11 | camp verde
# Processing Record 26 of Set 11 | melk
# Processing Record 27 of Set 11 | kiunga
# Processing Record 28 of Set 11 | qiongshan
# Processing Record 29 of Set 11 | lae
# Processing Record 30 of Set 11 | mutare
# Processing Record 31 of Set 11 | vanimo
# Processing Record 32 of Set 11 | monchegorsk
# Processing Record 33 of Set 11 | berasia
# Processing Record 34 of Set 11 | galle
# Processing Record 35 of Set 11 | boma
# Processing Record 36 of Set 11 | harper
# Processing Record 37 of Set 11 | palu
# Processing Record 38 of Set 11 | ipira
# Processing Record 39 of Set 11 | serik
# Processing Record 40 of Set 11 | gawler
# Processing Record 41 of Set 11 | charters towers
# Processing Record 42 of Set 11 | kosa
# Processing Record 43 of Set 11 | valparaiso
# Processing Record 44 of Set 11 | verkhnevilyuysk
# Processing Record 45 of Set 11 | aleksandrov gay
# Processing Record 46 of Set 11 | bafata
# Processing Record 47 of Set 11 | miedzyrzec podlaski
# Processing Record 48 of Set 11 | la maddalena
# Processing Record 49 of Set 11 | cayenne
# Processing Record 50 of Set 11 | shuangcheng
# Processing Record 1 of Set 12 | daru
# Processing Record 2 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 12 | north bend
# Processing Record 4 of Set 12 | georgiyevka
# Processing Record 5 of Set 12 | alekseyevsk
# Processing Record 6 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 12 | quatre cocos
# Processing Record 8 of Set 12 | siva
# Processing Record 9 of Set 12 | lagoa
# Processing Record 10 of Set 12 | ngudu
# Processing Record 11 of Set 12 | ulety
# Processing Record 12 of Set 12 | yarada
# Processing Record 13 of Set 12 | gazojak
# Processing Record 14 of Set 12 | banjar
# Processing Record 15 of Set 12 | ponta delgada
# Processing Record 16 of Set 12 | nizhniy kuranakh
# Processing Record 17 of Set 12 | voi
# Processing Record 18 of Set 12 | gorgan
# Processing Record 19 of Set 12 | luanda
# Processing Record 20 of Set 12 | dongsheng
# Processing Record 21 of Set 12 | englehart
# Processing Record 22 of Set 12 | yanam
# Processing Record 23 of Set 12 | prince rupert
# Processing Record 24 of Set 12 | kuressaare
# Processing Record 25 of Set 12 | itaituba
# Processing Record 26 of Set 12 | hirara
# Processing Record 27 of Set 12 | necochea
# Processing Record 28 of Set 12 | qaqortoq
# Processing Record 29 of Set 12 | fayaoue
# Processing Record 30 of Set 12 | eyl
# Processing Record 31 of Set 12 | cabedelo
# Processing Record 32 of Set 12 | inhambane
# Processing Record 33 of Set 12 | patiya
# Processing Record 34 of Set 12 | lerwick
# Processing Record 35 of Set 12 | giurgeni
# Processing Record 36 of Set 12 | moranbah
# Processing Record 37 of Set 12 | manta
# Processing Record 38 of Set 12 | quesnel
# Processing Record 39 of Set 12 | itarema
# Processing Record 40 of Set 12 | maltahohe
# Processing Record 41 of Set 12 | ulkan
# Processing Record 42 of Set 12 | ayan
# Processing Record 43 of Set 12 | matara
# Processing Record 44 of Set 12 | kieta
# Processing Record 45 of Set 12 | high level
# Processing Record 46 of Set 12 | teknaf
# Processing Record 47 of Set 12 | orlik
# Processing Record 48 of Set 12 | mutsu
# Processing Record 49 of Set 12 | saint-gilles
# Processing Record 50 of Set 12 | machilipatnam
# Processing Record 1 of Set 13 | chernogorsk
# Processing Record 2 of Set 13 | honningsvag
# Processing Record 3 of Set 13 | sechura
# Processing Record 4 of Set 13 | yumbing
# Processing Record 5 of Set 13 | tahta
# Processing Record 6 of Set 13 | pozo colorado
# Processing Record 7 of Set 13 | ostrovnoy
# Processing Record 8 of Set 13 | neulengbach
# Processing Record 9 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 13 | iturama
# Processing Record 11 of Set 13 | jodhpur
# Processing Record 12 of Set 13 | kachug
# Processing Record 13 of Set 13 | nantucket
# Processing Record 14 of Set 13 | lorengau
# Processing Record 15 of Set 13 | aviles
# Processing Record 16 of Set 13 | gerash
# Processing Record 17 of Set 13 | port shepstone
# Processing Record 18 of Set 13 | puerto baquerizo moreno
# Processing Record 19 of Set 13 | kayerkan
# Processing Record 20 of Set 13 | bathsheba
# Processing Record 21 of Set 13 | bojonegoro
# Processing Record 22 of Set 13 | santa marta
# Processing Record 23 of Set 13 | buin
# Processing Record 24 of Set 13 | black river
# Processing Record 25 of Set 13 | najran
# Processing Record 26 of Set 13 | chicama
# Processing Record 27 of Set 13 | nouadhibou
# Processing Record 28 of Set 13 | pitimbu
# Processing Record 29 of Set 13 | payakumbuh
# Processing Record 30 of Set 13 | marsabit
# Processing Record 31 of Set 13 | nikolsk
# Processing Record 32 of Set 13 | paka
# Processing Record 33 of Set 13 | port lavaca
# Processing Record 34 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 13 | shenjiamen
# Processing Record 36 of Set 13 | biak
# Processing Record 37 of Set 13 | namatanai
# Processing Record 38 of Set 13 | tecoanapa
# Processing Record 39 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 13 | geneva
# Processing Record 41 of Set 13 | mazamet
# Processing Record 42 of Set 13 | ifakara
# Processing Record 43 of Set 13 | lavrentiya
# Processing Record 44 of Set 13 | padang
# Processing Record 45 of Set 13 | bada
# Processing Record 46 of Set 13 | ilulissat
# Processing Record 47 of Set 13 | hue
# Processing Record 48 of Set 13 | asfi
# Processing Record 49 of Set 13 | boshnyakovo
# Processing Record 50 of Set 13 | colon
# Processing Record 1 of Set 14 | itoman
# Processing Record 2 of Set 14 | el cope
# Processing Record 3 of Set 14 | boden
# Processing Record 4 of Set 14 | zhaotong
# Processing Record 5 of Set 14 | naze
# Processing Record 6 of Set 14 | pong
# Processing Record 7 of Set 14 | masuguru
# Processing Record 8 of Set 14 | dalvik
# Processing Record 9 of Set 14 | sydney
# Processing Record 10 of Set 14 | rancho palos verdes
# Processing Record 11 of Set 14 | zomin
# Processing Record 12 of Set 14 | puerto del rosario
# Processing Record 13 of Set 14 | adrar
# Processing Record 14 of Set 14 | catuday
# Processing Record 15 of Set 14 | mecca
# Processing Record 16 of Set 14 | gat
# Processing Record 17 of Set 14 | sorong
# Processing Record 18 of Set 14 | sundumbili
# Processing Record 19 of Set 14 | camoapa
# Processing Record 20 of Set 14 | san jose
# Processing Record 21 of Set 14 | salaberry-de-valleyfield
# Processing Record 22 of Set 14 | saint-omer
# Processing Record 23 of Set 14 | robe
# Processing Record 24 of Set 14 | macas
# Processing Record 25 of Set 14 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 26 of Set 14 | salinas
# Processing Record 27 of Set 14 | malesici
# Processing Record 28 of Set 14 | aksarka
# Processing Record 29 of Set 14 | lodja
# Processing Record 30 of Set 14 | port-gentil
# Processing Record 31 of Set 14 | mariental
# Processing Record 32 of Set 14 | beloha
# Processing Record 33 of Set 14 | concordia
# Processing Record 34 of Set 14 | stillwater
# Processing Record 35 of Set 14 | arlit
# Processing Record 36 of Set 14 | kashi
# Processing Record 37 of Set 14 | kargasok
# Processing Record 38 of Set 14 | ifanadiana
# Processing Record 39 of Set 14 | shitanjing
# Processing Record 40 of Set 14 | dakar
# Processing Record 41 of Set 14 | mahuva
# Processing Record 42 of Set 14 | houma
# Processing Record 43 of Set 14 | sept-iles
# Processing Record 44 of Set 14 | mehamn
# Processing Record 45 of Set 14 | bereda
# Processing Record 46 of Set 14 | marseille
# Processing Record 47 of Set 14 | asosa
# Processing Record 48 of Set 14 | sambava
# Processing Record 49 of Set 14 | havelock
# Processing Record 50 of Set 14 | trelew
# Processing Record 1 of Set 15 | buchanan
# Processing Record 2 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 15 | itoigawa
# Processing Record 4 of Set 15 | jiwani
# Processing Record 5 of Set 15 | malanje
# Processing Record 6 of Set 15 | biltine
# Processing Record 7 of Set 15 | pangai
# Processing Record 8 of Set 15 | acarau
# Processing Record 9 of Set 15 | les cayes
# Processing Record 10 of Set 15 | pokanayevka
# City not found. Skipping...
# Processing Record 11 of Set 15 | cocorit
# Processing Record 12 of Set 15 | teya
# Processing Record 13 of Set 15 | korsakov
# Processing Record 14 of Set 15 | baiyin
# Processing Record 15 of Set 15 | kindu
# Processing Record 16 of Set 15 | ayni
# Processing Record 17 of Set 15 | tabora
# Processing Record 18 of Set 15 | fortuna
# Processing Record 19 of Set 15 | gamboula
# Processing Record 20 of Set 15 | feijo
# Processing Record 21 of Set 15 | leninskoye
# Processing Record 22 of Set 15 | saraza
# Processing Record 23 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 24 of Set 15 | muravlenko
# Processing Record 25 of Set 15 | shieli
# Processing Record 26 of Set 15 | huarmey
# Processing Record 27 of Set 15 | dajal
# Processing Record 28 of Set 15 | camacha
# Processing Record 29 of Set 15 | koster
# Processing Record 30 of Set 15 | rio gallegos
# Processing Record 31 of Set 15 | svetlyy
# Processing Record 32 of Set 15 | ribas do rio pardo
# Processing Record 33 of Set 15 | simao
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
x = len(city_data)
print(x)
# Out:
# 678

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Georgetown   5.4112  100.3354     81.90        82          20        1.01
# 1     Cherskiy  68.7500  161.3000    -48.86       100          76        4.00
# 2    Busselton -33.6500  115.3333     75.04        43           5        8.37
# 3      Wasilla  61.5814 -149.4394     33.73        74         100        8.01
# 4        Timra  62.4870   17.3257     21.67        60           5       11.50
# 5     Saldanha -33.0117   17.9442     66.67        84           0       11.23
# 6       Albany  42.6001  -73.9662     19.62        50           8        1.01
# 7        Bluff -46.6000  168.3333     55.80        76         100       18.19
# 8    Micheweni  -4.9667   39.8333     82.04        79         100       15.01
# 9  Yellowknife  62.4560 -114.3525    -19.71        67          15        5.01
#
#   Country Current Description
# 0      MY          few clouds
# 1      RU       broken clouds
# 2      AU           clear sky
# 3      US     overcast clouds
# 4      SE           clear sky
# 5      ZA           clear sky
# 6      US           clear sky
# 7      NZ     overcast clouds
# 8      TZ     overcast clouds
# 9      CA          few clouds

# %%
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Georgetown      MY   5.4112  100.3354     81.90        82          20
# 1     Cherskiy      RU  68.7500  161.3000    -48.86       100          76
# 2    Busselton      AU -33.6500  115.3333     75.04        43           5
# 3      Wasilla      US  61.5814 -149.4394     33.73        74         100
# 4        Timra      SE  62.4870   17.3257     21.67        60           5
# 5     Saldanha      ZA -33.0117   17.9442     66.67        84           0
# 6       Albany      US  42.6001  -73.9662     19.62        50           8
# 7        Bluff      NZ -46.6000  168.3333     55.80        76         100
# 8    Micheweni      TZ  -4.9667   39.8333     82.04        79         100
# 9  Yellowknife      CA  62.4560 -114.3525    -19.71        67          15
#
#    Wind Speed Current Description
# 0        1.01          few clouds
# 1        4.00       broken clouds
# 2        8.37           clear sky
# 3        8.01     overcast clouds
# 4       11.50           clear sky
# 5       11.23           clear sky
# 6        1.01           clear sky
# 7       18.19     overcast clouds
# 8       15.01     overcast clouds
# 9        5.01          few clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
