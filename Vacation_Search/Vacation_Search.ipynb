# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv")
city_data_df.head()
# Out:
#    City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  Georgetown      MY   5.4112  100.3354     81.90        82
# 1        1    Cherskiy      RU  68.7500  161.3000    -48.86       100
# 2        2   Busselton      AU -33.6500  115.3333     75.04        43
# 3        3     Wasilla      US  61.5814 -149.4394     33.73        74
# 4        4       Timra      SE  62.4870   17.3257     21.67        60
#
#    Cloudiness  Wind Speed Current Description
# 0          20        1.01          few clouds
# 1          76        4.00       broken clouds
# 2           5        8.37           clear sky
# 3         100        8.01     overcast clouds
# 4           5       11.50           clear sky

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
selected_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
selected_cities_df.head()
# Out:
#     City_ID        City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0  Georgetown      MY   5.4112  100.3354     81.90        82
# 2         2   Busselton      AU -33.6500  115.3333     75.04        43
# 8         8   Micheweni      TZ  -4.9667   39.8333     82.04        79
# 12       12   Mahebourg      MU -20.4081   57.7000     82.69        89
# 15       15     Rikitea      PF -23.1203 -134.9692     78.24        74
#
#     Cloudiness  Wind Speed Current Description
# 0           20        1.01          few clouds
# 2            5        8.37           clear sky
# 8          100       15.01     overcast clouds
# 12          40       18.41    scattered clouds
# 15         100        8.46     overcast clouds

# %%
selected_cities_df.count()
# Out:
# City_ID                195
# City                   195
# Country                193
# Lat                    195
# Lng                    195
# Max Temp               195
# Humidity               195
# Cloudiness             195
# Wind Speed             195
# Current Description    195
# dtype: int64

# %%
# 4a. Determine if there are any empty rows.
np.where(pd.isnull(selected_cities_df))
#selected_cities_df.iloc[22,2]
# Out:
# (array([ 22, 182]), array([2, 2]))

# %%
nan_values = selected_cities_df[selected_cities_df.isna().any(axis=1)]
nan_values
# Out:
#      City_ID       City Country      Lat      Lng  Max Temp  Humidity  \
# 80        80   Luderitz     NaN -26.6481  15.1594     77.52        63
# 628      628  Mariental     NaN -24.6333  17.9667     80.56        45
#
#      Cloudiness  Wind Speed Current Description
# 80           63        7.02       broken clouds
# 628         100        7.85     overcast clouds

# %%
selected_cities_df['Country'] = selected_cities_df['Country'].replace(np.nan, 'NA')
selected_cities_df.head(25)
# Out:
# /var/folders/5r/73b00_wd32537r9mr6y3f14h0000gn/T/ipykernel_15424/3748342788.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_cities_df['Country'] = selected_cities_df['Country'].replace(np.nan, 'NA')
#     City_ID             City Country      Lat       Lng  Max Temp  Humidity  \
# 0         0       Georgetown      MY   5.4112  100.3354     81.90        82
# 2         2        Busselton      AU -33.6500  115.3333     75.04        43
# 8         8        Micheweni      TZ  -4.9667   39.8333     82.04        79
# 12       12        Mahebourg      MU -20.4081   57.7000     82.69        89
# 15       15          Rikitea      PF -23.1203 -134.9692     78.24        74
# ...

# %%
selected_cities_df.count()
# Out:
# City_ID                195
# City                   195
# Country                195
# Lat                    195
# Lng                    195
# Max Temp               195
# Humidity               195
# Cloudiness             195
# Wind Speed             195
# Current Description    195
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
#No rows to drop. The two rows with cities in Namibia were replaced with country code NA from a NaN value.

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = selected_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 0    Georgetown      MY     81.90          few clouds   5.4112  100.3354
# 2     Busselton      AU     75.04           clear sky -33.6500  115.3333
# 8     Micheweni      TZ     82.04     overcast clouds  -4.9667   39.8333
# 12    Mahebourg      MU     82.69    scattered clouds -20.4081   57.7000
# 15      Rikitea      PF     78.24     overcast clouds -23.1203 -134.9692
# 18         Hilo      US     75.61       broken clouds  19.7297 -155.0900
# 19  Grand Gaube      MU     82.80          few clouds -20.0064   57.6608
# 20       Avarua      CK     78.85                haze -21.2078 -159.7750
# 21    Saint-Leu      RE     81.43          few clouds -21.1500   55.2833
# 27         Atar      MR     81.09     overcast clouds  20.5169  -13.0499
#
#    Hotel Name
# 0
# 2
# 8
# 12
# 15
# 18
# 19
# 20
# 21
# 27

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():

    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.loc[hotel_df['Hotel Name'] == ""].count()
# Out:
# City                   13
# Country                13
# Max Temp               13
# Current Description    13
# Lat                    13
# Lng                    13
# Hotel Name             13
# dtype: int64

# %%
# 7. Drop the rows where there is no Hotel Name.
#Alternate code: to drop rows with empty strings '' in DF.
#hotel_df.loc[hotel_df['Hotel Name'] == ""]
#hotel_df

#Code: to replace empty strings with NaN
hotel_df['Hotel Name'].replace('', np.nan, inplace=True)
hotel_df.head()
# Out:
#           City Country  Max Temp Current Description      Lat       Lng  \
# 0   Georgetown      MY     81.90          few clouds   5.4112  100.3354
# 2    Busselton      AU     75.04           clear sky -33.6500  115.3333
# 8    Micheweni      TZ     82.04     overcast clouds  -4.9667   39.8333
# 12   Mahebourg      MU     82.69    scattered clouds -20.4081   57.7000
# 15     Rikitea      PF     78.24     overcast clouds -23.1203 -134.9692
#
#                             Hotel Name
# 0                       Cititel Penang
# 2              Observatory Guest House
# 8                                  NaN
# 12  Shandrani Beachcomber Resort & Spa
# 15                     People ThankYou

# %%
#Code: to drop rows with NaN values
hotel_df.dropna(subset=['Hotel Name'], inplace=True)
hotel_df
# Out:
#            City Country  Max Temp Current Description      Lat       Lng  \
# 0    Georgetown      MY     81.90          few clouds   5.4112  100.3354
# 2     Busselton      AU     75.04           clear sky -33.6500  115.3333
# 12    Mahebourg      MU     82.69    scattered clouds -20.4081   57.7000
# 15      Rikitea      PF     78.24     overcast clouds -23.1203 -134.9692
# 18         Hilo      US     75.61       broken clouds  19.7297 -155.0900
# ..          ...     ...       ...                 ...      ...       ...
# 655   Les Cayes      HT     82.83          few clouds  18.2000  -73.7500
# 656     Cocorit      MX     75.54           clear sky  27.5833 -109.9667
# 665       Feijo      BR     81.81     overcast clouds  -8.1642  -70.3536
# 667      Saraza      PH     77.72     overcast clouds   8.7356  117.7800
# 670     Huarmey      PE     77.14          few clouds -10.0681  -78.1522
#
#                              Hotel Name
# 0                        Cititel Penang
# ...

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description} and {Max Temp} °F</dd>

</dl>
"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
